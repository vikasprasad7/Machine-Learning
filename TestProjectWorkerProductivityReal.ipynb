# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('D:\Downloads\Other\Data\AssignmentData.xlsx', 'WorkerFunnel')
df.head()
# Out:
#                   Date Quarter Department Targeted Productivity Overtime  \
# 0  2015-01-01 00:00:00      Q1     Sewing                   0.8     7080
# 1  2015-01-01 00:00:00      Q1  Finishing                  0.75      960
# 2  2015-01-01 00:00:00      Q1     Sewing                   0.8     3660
# 3  2015-01-01 00:00:00      Q1     Sewing                   0.8     3660
# 4  2015-01-01 00:00:00      Q1     Sewing                   0.8     1920
#
#   No. of Workers Actual Productivity
# 0             59            0.940725
# 1              8              0.8865
# 2           30.5             0.80057
# 3           30.5             0.80057
# 4             56                 NaN

# %%
df.tail()
# Out:
#                      Date Quarter Department Targeted Productivity Overtime  \
# 1192  2015-11-03 00:00:00      Q2  Finishing                  0.75      960
# 1193  2015-11-03 00:00:00      Q2  Finishing                   0.7      960
# 1194  2015-11-03 00:00:00      Q2  Finishing                  0.65      960
# 1195  2015-11-03 00:00:00      Q2  Finishing                  0.75     1800
# 1196  2015-11-03 00:00:00      Q2  Finishing                   0.7      720
#
#      No. of Workers Actual Productivity
# 1192              8            0.628333
# 1193              8                 NaN
# 1194              8            0.625625
# 1195             15            0.505889
# 1196              6            0.394722

# %%
df.shape
# Out:
# (1197, 7)

# %%
df.describe()
# Out:
#                        Date Quarter Department  Targeted Productivity  \
# count                  1197    1197       1197                 1197.0
# unique                   59       5          2                   10.0
# top     2015-11-03 00:00:00      Q1     Sewing                    0.8
# freq                     24     360        691                  539.0
#
#         Overtime  No. of Workers  Actual Productivity
# count       1197            1197          1168.000000
# unique       144              62           867.000000
# top          960               8             0.800402
# freq         129             262            24.000000

# %%
df.dtypes
# Out:
# Date                     object
# Quarter                  object
# Department               object
# Targeted Productivity    object
# Overtime                 object
# No. of Workers           object
# Actual Productivity      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   1197 non-null   object
#  1   Quarter                1197 non-null   object
#  2   Department             1197 non-null   object
#  3   Targeted Productivity  1197 non-null   object
#  4   Overtime               1197 non-null   object
#  5   No. of Workers         1197 non-null   object
#  6   Actual Productivity    1168 non-null   object
# dtypes: object(7)
# memory usage: 65.6+ KB

# %%
df.isnull().sum()
# Out:
# Date                      0
# Quarter                   0
# Department                0
# Targeted Productivity     0
# Overtime                  0
# No. of Workers            0
# Actual Productivity      29
# dtype: int64

# %%
df.dropna(how='any', inplace=True)

# %%
#I have removed the entire row with the missing data as it is a small amount of data that is missing

# %%
df.isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      0
# dtype: int64

# %%
df.shape
# Out:
# (1168, 7)

# %%
df[['Date','Quarter','Department','Targeted Productivity','Overtime','No. of Workers','Actual Productivity']]
# Out:
#                      Date Quarter Department Targeted Productivity Overtime  \
# 0     2015-01-01 00:00:00      Q1     Sewing                   0.8     7080
# 1     2015-01-01 00:00:00      Q1  Finishing                  0.75      960
# 2     2015-01-01 00:00:00      Q1     Sewing                   0.8     3660
# 3     2015-01-01 00:00:00      Q1     Sewing                   0.8     3660
# 5     2015-01-01 00:00:00      Q1     Sewing                   0.8     6720
# ...                   ...     ...        ...                   ...      ...
# 1191  2015-11-03 00:00:00      Q2     Sewing                  0.65     6840
# 1192  2015-11-03 00:00:00      Q2  Finishing                  0.75      960
# 1194  2015-11-03 00:00:00      Q2  Finishing                  0.65      960
# 1195  2015-11-03 00:00:00      Q2  Finishing                  0.75     1800
# 1196  2015-11-03 00:00:00      Q2  Finishing                   0.7      720
#
#      No. of Workers Actual Productivity
# ...

# %%
df['Date'].value_counts()
# Out:
# 2015-11-01 00:00:00    23
# 1/31/2015              23
# 2015-10-03 00:00:00    23
# 2015-11-03 00:00:00    22
# 1/24/2015              22
# 2015-09-03 00:00:00    22
# 1/13/2015              22
# 2015-12-01 00:00:00    22
# 1/22/2015              22
# 2015-10-01 00:00:00    22
# 2015-05-01 00:00:00    22
# 2015-07-01 00:00:00    22
# 2/26/2015              21
# 2/28/2015              21
# 2015-03-01 00:00:00    21
# 2015-03-03 00:00:00    21
# 2015-04-01 00:00:00    21
# 2015-08-01 00:00:00    21
# 2/18/2015              21
# 2015-08-03 00:00:00    21
# 1/17/2015              21
# 1/14/2015              21
# 1/28/2015              20
# 2015-04-03 00:00:00    20
# 1/27/2015              20
# 2/19/2015              20
# 1/29/2015              20
# 2/22/2015              20
# 2015-02-03 00:00:00    20
# 1/25/2015              20
# 2015-06-01 00:00:00    20
# 2/23/2015              19
# 2/17/2015              19
# 2/25/2015              19
# 2015-07-03 00:00:00    19
# ...

# %%
df['Quarter'].value_counts()
# Out:
# Q1    351
# Q2    328
# Q4    241
# Q3    205
# Q5     43
# Name: Quarter, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Sewing       672
# Finishing    496
# Name: Department, dtype: int64

# %%
df.Date.unique()
# Out:
# array([datetime.datetime(2015, 1, 1, 0, 0),
#        datetime.datetime(2015, 3, 1, 0, 0),
#        datetime.datetime(2015, 4, 1, 0, 0),
#        datetime.datetime(2015, 5, 1, 0, 0),
#        datetime.datetime(2015, 6, 1, 0, 0),
#        datetime.datetime(2015, 7, 1, 0, 0),
#        datetime.datetime(2015, 8, 1, 0, 0),
#        datetime.datetime(2015, 10, 1, 0, 0),
#        datetime.datetime(2015, 11, 1, 0, 0),
#        datetime.datetime(2015, 12, 1, 0, 0), '1/13/2015', '1/14/2015',
#        '1/15/2015', '1/17/2015', '1/18/2015', '1/19/2015', '1/20/2015',
#        '1/21/2015', '1/22/2015', '1/24/2015', '1/25/2015', '1/26/2015',
#        '1/27/2015', '1/28/2015', '1/29/2015', '1/31/2015',
#        datetime.datetime(2015, 1, 2, 0, 0),
#        datetime.datetime(2015, 2, 2, 0, 0),
#        datetime.datetime(2015, 3, 2, 0, 0),
#        datetime.datetime(2015, 4, 2, 0, 0),
#        datetime.datetime(2015, 5, 2, 0, 0),
#        datetime.datetime(2015, 7, 2, 0, 0),
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date']
# Out:
# 0      2015-01-01
# 1      2015-01-01
# 2      2015-01-01
# 3      2015-01-01
# 5      2015-01-01
#           ...
# 1191   2015-11-03
# 1192   2015-11-03
# 1194   2015-11-03
# 1195   2015-11-03
# 1196   2015-11-03
# Name: Date, Length: 1168, dtype: datetime64[ns]

# %%
df.Date.unique()
# Out:
# array(['2015-01-01T00:00:00.000000000', '2015-03-01T00:00:00.000000000',
#        '2015-04-01T00:00:00.000000000', '2015-05-01T00:00:00.000000000',
#        '2015-06-01T00:00:00.000000000', '2015-07-01T00:00:00.000000000',
#        '2015-08-01T00:00:00.000000000', '2015-10-01T00:00:00.000000000',
#        '2015-11-01T00:00:00.000000000', '2015-12-01T00:00:00.000000000',
#        '2015-01-13T00:00:00.000000000', '2015-01-14T00:00:00.000000000',
#        '2015-01-15T00:00:00.000000000', '2015-01-17T00:00:00.000000000',
#        '2015-01-18T00:00:00.000000000', '2015-01-19T00:00:00.000000000',
#        '2015-01-20T00:00:00.000000000', '2015-01-21T00:00:00.000000000',
#        '2015-01-22T00:00:00.000000000', '2015-01-24T00:00:00.000000000',
#        '2015-01-25T00:00:00.000000000', '2015-01-26T00:00:00.000000000',
#        '2015-01-27T00:00:00.000000000', '2015-01-28T00:00:00.000000000',
#        '2015-01-29T00:00:00.000000000', '2015-01-31T00:00:00.000000000',
# ...

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df.head()
# Out:
#         Date Quarter Department Targeted Productivity Overtime No. of Workers  \
# 0 2015-01-01      Q1     Sewing                   0.8     7080             59
# 1 2015-01-01      Q1  Finishing                  0.75      960              8
# 2 2015-01-01      Q1     Sewing                   0.8     3660           30.5
# 3 2015-01-01      Q1     Sewing                   0.8     3660           30.5
# 5 2015-01-01      Q1     Sewing                   0.8     6720             56
#
#   Actual Productivity  Year  Month  Day
# 0            0.940725  2015      1    1
# 1              0.8865  2015      1    1
# 2             0.80057  2015      1    1
# 3             0.80057  2015      1    1
# 5            0.800125  2015      1    1

# %%
quarter = {'Q1':1, 'Q2':2, 'Q3':3, 'Q4':4, 'Q5':5}
df['Quarter'] = df['Quarter'].map(quarter)

# %%
dept = {'Sewing':1, 'Finishing':2}
df['Department'] = df['Department'].map(dept)

# %%
df.head()
# Out:
#         Date  Quarter  Department Targeted Productivity Overtime  \
# 0 2015-01-01        1           1                   0.8     7080
# 1 2015-01-01        1           2                  0.75      960
# 2 2015-01-01        1           1                   0.8     3660
# 3 2015-01-01        1           1                   0.8     3660
# 5 2015-01-01        1           1                   0.8     6720
#
#   No. of Workers Actual Productivity  Year  Month  Day
# 0             59            0.940725  2015      1    1
# 1              8              0.8865  2015      1    1
# 2           30.5             0.80057  2015      1    1
# 3           30.5             0.80057  2015      1    1
# 5             56            0.800125  2015      1    1

# %%
df.dtypes
# Out:
# Date                     datetime64[ns]
# Quarter                           int64
# Department                        int64
# Targeted Productivity            object
# Overtime                         object
# No. of Workers                   object
# Actual Productivity              object
# Year                              int64
# Month                             int64
# Day                               int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 0 to 1196
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   1168 non-null   datetime64[ns]
#  1   Quarter                1168 non-null   int64
#  2   Department             1168 non-null   int64
#  3   Targeted Productivity  1168 non-null   object
#  4   Overtime               1168 non-null   object
#  5   No. of Workers         1168 non-null   object
#  6   Actual Productivity    1168 non-null   object
#  7   Year                   1168 non-null   int64
#  8   Month                  1168 non-null   int64
#  9   Day                    1168 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(4)
# memory usage: 100.4+ KB

# %%
#First find how to locate such rows
message = {'What do you think should be here?':0.8}

# %%
df['Targeted Productivity'] = pd.to_numeric(df['Targeted Productivity'], errors='coerce')

# %%
df['Targeted Productivity'][50:70:1]
# Out:
# 52    0.80
# 53    0.70
# 54    0.75
# 55    0.75
# 56    0.70
# 57    0.80
# 58    0.80
# 59    0.70
# 60    0.75
# 61    0.80
# 62    0.80
# 63    0.80
# 64    0.75
# 65    0.80
# 66    0.80
# 67     NaN
# 68    0.80
# 69    0.80
# 70    0.80
# 71    0.80
# Name: Targeted Productivity, dtype: float64

# %%
df['Targeted Productivity'].isnull().sum()
# Out:
# 1

# %%
text = df['Targeted Productivity'].isnull()
#Now we have to convert this to a number-value

# %%
print(df[text])
# Out:
#          Date  Quarter  Department  Targeted Productivity Overtime  \
# 67 2015-05-01        1           2                    NaN      960
#
#    No. of Workers Actual Productivity  Year  Month  Day
# 67              8            0.804417  2015      5    1

# %%
print(text)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 1191    False
# 1192    False
# 1194    False
# 1195    False
# 1196    False
# Name: Targeted Productivity, Length: 1168, dtype: bool

# %%
print(df['Targeted Productivity'].dtype)
# Out:
# float64

# %%
#funnel['Targeted Productivity_num'].ffill(funnel['Targeted Productivity_num'].mean(),inplace=True)
df['Targeted Productivity'].fillna(value=df['Targeted Productivity'].mean(),inplace=True)

# %%
df['Targeted Productivity'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 0 to 1196
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   1168 non-null   datetime64[ns]
#  1   Quarter                1168 non-null   int64
#  2   Department             1168 non-null   int64
#  3   Targeted Productivity  1168 non-null   float64
#  4   Overtime               1168 non-null   object
#  5   No. of Workers         1168 non-null   object
#  6   Actual Productivity    1168 non-null   object
#  7   Year                   1168 non-null   int64
#  8   Month                  1168 non-null   int64
#  9   Day                    1168 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 100.4+ KB

# %%
print(df['Overtime'].dtype)
# Out:
# object

# %%
df['Overtime'] = pd.to_numeric(df['Overtime'], errors='coerce')

# %%
df['Overtime'].isnull().sum()
# Out:
# 1

# %%
print(df['Overtime'].dtype)
# Out:
# float64

# %%
df['Overtime'].fillna(value=df['Overtime'].mean(), inplace=True)

# %%
df['Overtime'].isnull().sum()
# Out:
# 0

# %%
print(df['No. of Workers'].dtype)
# Out:
# object

# %%
df['No. of Workers'] = pd.to_numeric(df['No. of Workers'], errors='coerce')

# %%
df['No. of Workers'].isnull().sum()
# Out:
# 1

# %%
print(df['No. of Workers'].dtype)
# Out:
# float64

# %%
df['No. of Workers'].fillna(value=df['No. of Workers'].mean(), inplace=True)

# %%
df['No. of Workers'].isnull().sum()
# Out:
# 0

# %%
print(df['Actual Productivity'].dtype)
# Out:
# object

# %%
df['Actual Productivity'] = pd.to_numeric(df['Actual Productivity'], errors='coerce')

# %%
df['Actual Productivity'].isnull().sum()
# Out:
# 1

# %%
print(df['Actual Productivity'].dtype)
# Out:
# float64

# %%
df['Actual Productivity'].fillna(value=df['Actual Productivity'].mean(),inplace=True)

# %%
df['Actual Productivity'].isnull().sum()
# Out:
# 0

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 0 to 1196
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   1168 non-null   datetime64[ns]
#  1   Quarter                1168 non-null   int64
#  2   Department             1168 non-null   int64
#  3   Targeted Productivity  1168 non-null   float64
#  4   Overtime               1168 non-null   float64
#  5   No. of Workers         1168 non-null   float64
#  6   Actual Productivity    1168 non-null   float64
#  7   Year                   1168 non-null   int64
#  8   Month                  1168 non-null   int64
#  9   Day                    1168 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(5)
# memory usage: 100.4 KB

# %%
df.head()
# Out:
#         Date  Quarter  Department  Targeted Productivity  Overtime  \
# 0 2015-01-01        1           1                   0.80    7080.0
# 1 2015-01-01        1           2                   0.75     960.0
# 2 2015-01-01        1           1                   0.80    3660.0
# 3 2015-01-01        1           1                   0.80    3660.0
# 5 2015-01-01        1           1                   0.80    6720.0
#
#    No. of Workers  Actual Productivity  Year  Month  Day
# 0            59.0             0.940725  2015      1    1
# 1             8.0             0.886500  2015      1    1
# 2            30.5             0.800570  2015      1    1
# 3            30.5             0.800570  2015      1    1
# 5            56.0             0.800125  2015      1    1

# %%
df.tail()
# Out:
#            Date  Quarter  Department  Targeted Productivity  Overtime  \
# 1191 2015-11-03        2           1                   0.65    6840.0
# 1192 2015-11-03        2           2                   0.75     960.0
# 1194 2015-11-03        2           2                   0.65     960.0
# 1195 2015-11-03        2           2                   0.75    1800.0
# 1196 2015-11-03        2           2                   0.70     720.0
#
#       No. of Workers  Actual Productivity  Year  Month  Day
# 1191            57.0             0.650596  2015     11    3
# 1192             8.0             0.628333  2015     11    3
# 1194             8.0             0.625625  2015     11    3
# 1195            15.0             0.505889  2015     11    3
# 1196             6.0             0.394722  2015     11    3

# %%
df.reset_index()
# Out:
#       index       Date  Quarter  Department  Targeted Productivity  Overtime  \
# 0         0 2015-01-01        1           1                   0.80    7080.0
# 1         1 2015-01-01        1           2                   0.75     960.0
# 2         2 2015-01-01        1           1                   0.80    3660.0
# 3         3 2015-01-01        1           1                   0.80    3660.0
# 4         5 2015-01-01        1           1                   0.80    6720.0
# ...     ...        ...      ...         ...                    ...       ...
# 1163   1191 2015-11-03        2           1                   0.65    6840.0
# 1164   1192 2015-11-03        2           2                   0.75     960.0
# 1165   1194 2015-11-03        2           2                   0.65     960.0
# 1166   1195 2015-11-03        2           2                   0.75    1800.0
# 1167   1196 2015-11-03        2           2                   0.70     720.0
#
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 5       False
#         ...
# 1191    False
# 1192    False
# 1194    False
# 1195    False
# 1196    False
# Length: 1168, dtype: bool

# %%
df[df.duplicated()]
# Out:
#            Date  Quarter  Department  Targeted Productivity  Overtime  \
# 3    2015-01-01        1           1                   0.80    3660.0
# 27   2015-03-01        1           1                   0.80    7080.0
# 31   2015-03-01        1           1                   0.80    6720.0
# 69   2015-05-01        1           1                   0.80    6780.0
# 73   2015-05-01        1           1                   0.80    7200.0
# 75   2015-05-01        1           1                   0.80    6900.0
# 89   2015-06-01        1           1                   0.80   10620.0
# 93   2015-06-01        1           1                   0.80   10350.0
# 97   2015-06-01        1           1                   0.80   10170.0
# 107  2015-07-01        1           1                   0.80   10620.0
# 115  2015-07-01        1           1                   0.80   10350.0
# 133  2015-08-01        2           1                   0.80   10170.0
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index()
# Out:
#       index       Date  Quarter  Department  Targeted Productivity  Overtime  \
# 0         0 2015-01-01        1           1                   0.80    7080.0
# 1         1 2015-01-01        1           2                   0.75     960.0
# 2         2 2015-01-01        1           1                   0.80    3660.0
# 3         5 2015-01-01        1           1                   0.80    6720.0
# 4         6 2015-01-01        1           2                   0.75     960.0
# ...     ...        ...      ...         ...                    ...       ...
# 1128   1191 2015-11-03        2           1                   0.65    6840.0
# 1129   1192 2015-11-03        2           2                   0.75     960.0
# 1130   1194 2015-11-03        2           2                   0.65     960.0
# 1131   1195 2015-11-03        2           2                   0.75    1800.0
# 1132   1196 2015-11-03        2           2                   0.70     720.0
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import root_mean_squared_error, mean_absolute_error

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data Visualization

# %%
sns.countplot(x='Quarter', data=df)
# Out:
# <Axes: xlabel='Quarter', ylabel='count'>

# %%
df.boxplot(column='Quarter')
plt.title('Boxplot of Quarter')
plt.ylabel('Value')
plt.show()

# %%
sns.boxplot(x='Quarter', y='Actual Productivity', data=df)
plt.title('Relationship between Actual Productivity and Quarter')
plt.xlabel('Quarter')
plt.ylabel('Actual Productivity')
plt.show()
#here median tells high and low productivity
#up is higher down is lower any aspect

# %%
#Group by Quarter
#compare distributions for Quarter 1, 2, 3, 4, 5
sns.histplot(data=df, x='Actual Productivity', hue='Quarter', kde=True, element='step')
# Out:
# <Axes: xlabel='Actual Productivity', ylabel='Count'>

# %%
from scipy.stats import f_oneway
f_oneway(
    df[df['Quarter'] == 1]['Actual Productivity'],
    df[df['Quarter'] == 2]['Actual Productivity'],
    df[df['Quarter'] == 3]['Actual Productivity'],
    df[df['Quarter'] == 4]['Actual Productivity'],
    df[df['Quarter'] == 5]['Actual Productivity']
)
# Out:
# F_onewayResult(statistic=6.252087093506194, pvalue=5.629715813843281e-05)

# %%
#Feature engineering
df['High Productivity Quarter'] = df['Quarter'].apply(lambda x: 1 if x == 5 else 0)

# %%
sns.countplot(x='Department', data=df)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
df.boxplot(column='Department')
plt.title('Boxplot of Department')
plt.ylabel('Value')
plt.show()

# %%
sns.boxplot(x='Department', y='Actual Productivity', data=df)
plt.title('Relationship between Actual Productivity and Department')
plt.xlabel('Department')
plt.ylabel('Actual Productivity')
plt.show()

# %%
#Group by Department
#compare distributions for Department 1, 2
sns.histplot(data=df, x='Actual Productivity', hue='Department', kde=True, element='step')
# Out:
# <Axes: xlabel='Actual Productivity', ylabel='Count'>

# %%
f_oneway(
    df[df['Department'] == 1]['Actual Productivity'],
    df[df['Department'] == 2]['Actual Productivity'],
    )
# Out:
# F_onewayResult(statistic=9.915887318083033, pvalue=0.0016814978095950552)

# %%
#Feature engineering
df['High Productivity Department'] = df['Department'].apply(lambda x: 1 if x == 2 else 0)

# %%
df.head()
# Out:
#         Date  Quarter  Department  Targeted Productivity  Overtime  \
# 0 2015-01-01        1           1                   0.80    7080.0
# 1 2015-01-01        1           2                   0.75     960.0
# 2 2015-01-01        1           1                   0.80    3660.0
# 5 2015-01-01        1           1                   0.80    6720.0
# 6 2015-01-01        1           2                   0.75     960.0
#
#    No. of Workers  Actual Productivity  Year  Month  Day  \
# 0            59.0             0.940725  2015      1    1
# 1             8.0             0.886500  2015      1    1
# 2            30.5             0.800570  2015      1    1
# 5            56.0             0.800125  2015      1    1
# 6             8.0             0.755167  2015      1    1
#
#    High Productivity Quarter  High Productivity Department
# 0                          0                             0
# 1                          0                             1
# ...

# %%
sns.countplot(x='Targeted Productivity', data=df)
# Out:
# <Axes: xlabel='Targeted Productivity', ylabel='count'>

# %%
df.boxplot(column='Targeted Productivity')
plt.title('Boxplot of Targeted Productivity')
plt.ylabel('Value')
plt.show()

# %%
sns.boxplot(x='Targeted Productivity', y='Actual Productivity', data=df)
plt.title('Relationship between Actual Productivity and Targeted Productivity')
plt.xlabel('Targeted Productivity')
plt.ylabel('Actual Productivity')
plt.show()

# %%
#Group by Targeted Productivity
#compare distributions for Targeted Productivity
sns.histplot(data=df, x='Actual Productivity', hue='Targeted Productivity', kde=True, element='step')
# Out:
# <Axes: xlabel='Actual Productivity', ylabel='Count'>

# %%
#Feature engineering
df['High Targeted Productivity'] = df['Targeted Productivity'].apply(lambda x: 1 if x == 0.8 else 0)

# %%
df['Overtime'].hist(bins=30)
plt.title('Histogram of Overtime')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='Overtime')
plt.title('Boxplot of Overtime')
plt.ylabel('Value')
plt.show()

# %%
sns.scatterplot(x='Overtime', y='Actual Productivity', data=df)
plt.title('Relationship between Overtime and Actual Productivity')
plt.show()

# %%
#Overlay kde plot to understand shape and density
#just like histogram above
sns.histplot(df['Overtime'], kde=True)
# Out:
# <Axes: xlabel='Overtime', ylabel='Count'>

# %%
df['No. of Workers'].hist(bins=30)
plt.title('Histogram of No. of Workers')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='No. of Workers')
plt.title('Boxplot of No. of Workers')
plt.ylabel('Value')
plt.show()

# %%
sns.scatterplot(x='No. of Workers', y='Actual Productivity', data=df)
plt.title('Relationship between No. of Workers and Actual Productivity')
plt.show()

# %%
sns.countplot(x='Year', data=df)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
df.boxplot(column='Year')
plt.title('Boxplot of Year')
plt.ylabel('Value')
plt.show()

# %%
sns.boxplot(x='Year', y='Actual Productivity', data=df)
plt.title('Relationship between Year and Targeted Productivity')
plt.xlabel('Year')
plt.ylabel('Actual Productivity')
plt.show()

# %%
sns.countplot(x='Month', data=df)
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
df.boxplot(column='Month')
plt.title('Boxplot of Month')
plt.ylabel('Value')
plt.show()

# %%
sns.boxplot(x='Month', y='Actual Productivity', data=df)
plt.title('Relationship between Month and Actual Productivity')
plt.xlabel('Month')
plt.ylabel('Actual Productivity')
plt.show()

# %%
#Group by Month
#compare distributions for Month 1 to 12
sns.histplot(data=df, x='Actual Productivity', hue='Month', kde=True, element='step')
# Out:
# <Axes: xlabel='Actual Productivity', ylabel='Count'>

# %%
#feature engineering
df['High Productivity Month'] = df['Month'].apply(lambda x: 1 if x == 8 else 0)

# %%
sns.countplot(x='Day', data=df)
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %%
df.boxplot(column='Day')
plt.title('Boxplot of Day')
plt.ylabel('Value')
plt.show()

# %%
sns.boxplot(x='Day', y='Actual Productivity', data=df)
plt.title('Relationship between Day and Actual Productivity')
plt.xlabel('Day')
plt.ylabel('Actual Productivity')
plt.show()

# %%
#Feature engineering
df['High Productivity Day'] = df['Day'].apply(lambda x: 1 if x == 29 else 0)

# %%
#Implementing the model stacking in ensemble learning approach

# %%
X = df[['Quarter']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
#Polynomial Features

X = df[['Quarter']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) #tried with 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.02
# Root Mean Squared Error: 0.17
# Mean Absolute Error: 0.13

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
#Kfold polynomial

X = df[['Quarter']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=8) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [ 0.01980197 -0.00750777 -0.01746966  0.02239881  0.0321849 ]
# Average R2 score: 0.01
# Cross-Validation mse Scores: [-0.03057141 -0.02771402 -0.03261559 -0.02957383 -0.03097585]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17484681 -0.16647529 -0.18059787 -0.17197042 -0.17599957]
# Average rmse score: -0.17
# Cross-Validation mae Scores: [-0.13633077 -0.12416843 -0.14095386 -0.13431526 -0.13610762]
# Average mae score: -0.13

# %%
X = df[['Department']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['Department']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=4) #tried with 2=0.03, 3=0.03, 4=0.03
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['Department']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=8) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [-0.00803407  0.01354471  0.01641609 -0.02142037 -0.00043912]
# Average R2 score: 0.00
# Cross-Validation mse Scores: [-0.03143958 -0.02713492 -0.03152936 -0.03089942 -0.03202001]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17731211 -0.1647268  -0.1775651  -0.17578231 -0.17894137]
# Average rmse score: -0.17
# Cross-Validation mae Scores: [-0.13892578 -0.12572613 -0.14043595 -0.13680261 -0.140353  ]
# Average mae score: -0.14

# %%
X = df[['Targeted Productivity']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.18
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.11

# %%
#Polynomial Features
X = df[['Targeted Productivity']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0.03, 3=0.03, 4=0.03
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.10
# Root Mean Squared Error: 0.17
# Mean Absolute Error: 0.11

# %%
#Kfold polynomial

X = df[['Targeted Productivity']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [0.20428618 0.02692951 0.24407163 0.17939478 0.19755484]
# Average R2 score: 0.17
# Cross-Validation mse Scores: [-0.02481753 -0.02676674 -0.02423173 -0.02482448 -0.02568303]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.15753579 -0.16360543 -0.15566544 -0.15755785 -0.16025925]
# Average rmse score: -0.16
# Cross-Validation mae Scores: [-0.10889682 -0.10291991 -0.11067959 -0.11072411 -0.11338884]
# Average mae score: -0.11

# %%
X = df[['Overtime']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.00
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['Overtime']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0.03, 3=0.03, 4=0.03
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['Overtime']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [-0.0041118  -0.0120585  -0.02962154 -0.01099524  0.0012589 ]
# Average R2 score: -0.01
# Cross-Validation mse Scores: [-0.03131725 -0.0278392  -0.03300513 -0.03058404 -0.03196567]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17696681 -0.16685083 -0.18167313 -0.17488294 -0.17878945]
# Average rmse score: -0.18
# Cross-Validation mae Scores: [-0.13922672 -0.12635991 -0.14225847 -0.13612354 -0.1396854 ]
# Average mae score: -0.14

# %%
X = df[['No. of Workers']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['No. of Workers']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0.03, 3=0.03, 4=0.03
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.00
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['No. of Workers']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [-0.01002886  0.01388195  0.00375043 -0.01028074 -0.00420613]
# Average R2 score: -0.00
# Cross-Validation mse Scores: [-0.0315018  -0.02712564 -0.03193537 -0.03056243 -0.03214058]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17748746 -0.16469864 -0.1787047  -0.17482114 -0.17927794]
# Average rmse score: -0.17
# Cross-Validation mae Scores: [-0.13829368 -0.12466076 -0.14025701 -0.13477297 -0.14045752]
# Average mae score: -0.14

# %%
X = df[['Year']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.00
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['Year']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['Year']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [-0.00472313 -0.00159108 -0.00673384 -0.00489118 -0.00204485]
# Average R2 score: -0.00
# Cross-Validation mse Scores: [-0.03133632 -0.02755127 -0.03227145 -0.03039939 -0.03207141]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17702067 -0.16598574 -0.17964256 -0.1743542  -0.17908491]
# Average rmse score: -0.18
# Cross-Validation mae Scores: [-0.13923225 -0.12560409 -0.14160127 -0.13609215 -0.13969548]
# Average mae score: -0.14

# %%
X = df[['Month']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['Month']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=8) 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.01
# Root Mean Squared Error: 0.17
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['Month']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [ 0.00824274  0.00657171 -0.03555349  0.0010775  -0.00302455]
# Average R2 score: -0.00
# Cross-Validation mse Scores: [-0.03093193 -0.02732673 -0.03319528 -0.03021883 -0.03210276]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17587475 -0.16530798 -0.18219571 -0.17383563 -0.17917244]
# Average rmse score: -0.18
# Cross-Validation mae Scores: [-0.13773795 -0.12383222 -0.14350764 -0.13532486 -0.13935535]
# Average mae score: -0.14

# %%
X = df[['Day']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['Day']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=4) 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.03
# Root Mean Squared Error: 0.17
# Mean Absolute Error: 0.13

# %%
#Kfold polynomial

X = df[['Day']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [ 0.03430982  0.02215118 -0.02446731  0.00749745  0.01528319]
# Average R2 score: 0.01
# Cross-Validation mse Scores: [-0.03011892 -0.02689818 -0.0328399  -0.03002461 -0.03151681]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17354803 -0.16400664 -0.18121784 -0.17327612 -0.17752973]
# Average rmse score: -0.17
# Cross-Validation mae Scores: [-0.13409808 -0.12244582 -0.14197309 -0.13500752 -0.1376716 ]
# Average mae score: -0.13

# %%
X = df[['High Productivity Quarter']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['High Productivity Quarter']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.01
# Root Mean Squared Error: 0.17
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['High Productivity Quarter']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [-0.00778434 -0.00485409 -0.00106443  0.0161277   0.00909758]
# Average R2 score: 0.00
# Cross-Validation mse Scores: [-0.0314318  -0.02764102 -0.03208971 -0.02976354 -0.03171478]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17729014 -0.1662559  -0.17913601 -0.17252112 -0.17808645]
# Average rmse score: -0.17
# Cross-Validation mae Scores: [-0.13974923 -0.1262633  -0.14070108 -0.13462815 -0.13829838]
# Average mae score: -0.14

# %%
X = df[['High Productivity Department']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['High Productivity Department']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['High Productivity Department']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=2) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [-0.00803407  0.01354471  0.01641609 -0.02142037 -0.00043912]
# Average R2 score: 0.00
# Cross-Validation mse Scores: [-0.03143958 -0.02713492 -0.03152936 -0.03089942 -0.03202001]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17731211 -0.1647268  -0.1775651  -0.17578231 -0.17894137]
# Average rmse score: -0.17
# Cross-Validation mae Scores: [-0.13892578 -0.12572613 -0.14043595 -0.13680261 -0.140353  ]
# Average mae score: -0.14

# %%
X = df[['High Targeted Productivity']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.14
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.12

# %%
#Polynomial Features
X = df[['High Targeted Productivity']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.05
# Root Mean Squared Error: 0.17
# Mean Absolute Error: 0.13

# %%
#Kfold polynomial

X = df[['High Targeted Productivity']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [0.13896288 0.00681833 0.12729308 0.13309126 0.09706416]
# Average R2 score: 0.10
# Cross-Validation mse Scores: [-0.02685489 -0.02731995 -0.02797514 -0.02622522 -0.02889933]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.16387463 -0.16528746 -0.16725769 -0.16194203 -0.16999802]
# Average rmse score: -0.17
# Cross-Validation mae Scores: [-0.12162233 -0.11867024 -0.12506824 -0.11955787 -0.12678634]
# Average mae score: -0.12

# %%
X = df[['High Productivity Month']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.00
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['High Productivity Month']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['High Productivity Month']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [-0.0042723  -0.00281332 -0.00787911 -0.00421221 -0.01320299]
# Average R2 score: -0.01
# Cross-Validation mse Scores: [-0.03132226 -0.02758489 -0.03230816 -0.03037885 -0.03242853]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.17698095 -0.16608699 -0.17974471 -0.17429529 -0.18007924]
# Average rmse score: -0.18
# Cross-Validation mae Scores: [-0.13915442 -0.12569336 -0.14164408 -0.13604068 -0.14067028]
# Average mae score: -0.14

# %%
X = df[['High Productivity Day']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Polynomial Features
X = df[['High Productivity Day']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) 
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=43)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.01
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Kfold polynomial

X = df[['High Productivity Day']]
y = df['Actual Productivity']

poly = PolynomialFeatures(degree=3) #tried with 2=0,3=01,4=01,5=01,6=01,7=01,8=01
X_poly = poly.fit_transform(X)
poly_reg_model = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=44)
scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='r2')
print(f'Cross-Validation R2 Scores: {scores}')
print(f'Average R2 score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_squared_error')
print(f'Cross-Validation mse Scores: {scores}')
print(f'Average mse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_root_mean_squared_error')
print(f'Cross-Validation rmse Scores: {scores}')
print(f'Average rmse score: {scores.mean():.2f}')

scores = cross_val_score(poly_reg_model, X_poly, y, cv=kf, scoring='neg_mean_absolute_error')
print(f'Cross-Validation mae Scores: {scores}')
print(f'Average mae score: {scores.mean():.2f}')
# Out:
# Cross-Validation R2 Scores: [-1.23284734e-02 -1.52437464e-02 -1.23203357e-03  1.08383125e-06
#   5.88605439e-04]
# Average R2 score: -0.01
# Cross-Validation mse Scores: [-0.03157352 -0.02792682 -0.03209508 -0.03025139 -0.03198712]
# Average mse score: -0.03
# Cross-Validation rmse Scores: [-0.1776894  -0.16711319 -0.17915101 -0.17392927 -0.17884943]
# Average rmse score: -0.18
# Cross-Validation mae Scores: [-0.14000798 -0.12688776 -0.14086484 -0.13574422 -0.1390555 ]
# Average mae score: -0.14

# %%
df['OxW'] = df['Overtime'] * df['No. of Workers']

# %%
X = df[['OxW']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: -0.00
# Root Mean Squared Error: 0.18
# Mean Absolute Error: 0.14

# %%
#Model selection based on top performing models after running baseline models and recording top
#performers and combining high performing models

# %%
X = df[['High Targeted Productivity','Targeted Productivity']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.20
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.11

# %%
X = df[['Quarter','Department','Targeted Productivity','Month','Day','Overtime','No. of Workers']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.19
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.12

# %%
X = df[['Quarter','Department','Targeted Productivity','Month','Day','Overtime','No. of Workers','High Targeted Productivity']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.20
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.12

# %%
#Implementing the stacking approach

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
X = df[['High Targeted Productivity','Targeted Productivity']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
dt = DecisionTreeRegressor(max_depth=5, random_state=44)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.20
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.11

# %%
X = df[['Quarter','Department','Targeted Productivity','Month','Day','Overtime','No. of Workers']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
dt = DecisionTreeRegressor(max_depth=5, random_state=44)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.02
# R² Score: 0.20
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.11

# %%
X = df[['Quarter','Department','Targeted Productivity','Month','Day','Overtime','No. of Workers','High Targeted Productivity']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
dt = DecisionTreeRegressor(max_depth=5, random_state=44)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.02
# R² Score: 0.20
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.11

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X = df[['High Targeted Productivity','Targeted Productivity']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
rf = RandomForestRegressor(n_estimators=100, random_state=44)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.03
# R² Score: 0.20
# Root Mean Squared Error: 0.16
# Mean Absolute Error: 0.11

# %%
X = df[['Quarter','Department','Targeted Productivity','Month','Day','Overtime','No. of Workers']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
rf = RandomForestRegressor(n_estimators=100, random_state=44)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.02
# R² Score: 0.32
# Root Mean Squared Error: 0.15
# Mean Absolute Error: 0.10

# %%
X = df[['Quarter','Department','Targeted Productivity','Month','Day','Overtime','No. of Workers','High Targeted Productivity']]
y = df['Actual Productivity']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=44)
rf = RandomForestRegressor(n_estimators=100, random_state=44)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R² Score: {r2:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 0.02
# R² Score: 0.32
# Root Mean Squared Error: 0.15
# Mean Absolute Error: 0.10
